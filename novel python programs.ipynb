# %%
file_path=r"C:\Users\SwatiTiwari\Downloads\fsd.txt"

# %%
file_obj = open(file_path) #File path is the complete path of the file to be read 
file_contents =file_obj.readlines()

# %%
file_obj.close()

# %%
stopwords=r"C:\Users\SwatiTiwari\Downloads\bd.txt"#not used in the programs below

# %%
stop_obj = open(stopwords) #File path is the complete path of the file to be read 
stop_contents = str(stop_obj.readlines())

# %%
d={"fucked up":0,"bitch":0,"fuck":0,"kiss":0}
sensitive_word=["fucked up","bitch","fuck","kiss"]

# %%
stop_obj.close()

# %%
stoplist=stop_contents.split()

# %%
import string
file_contents_cleaned = []
#wordlist=file_contents.split()
type(wordlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 file_contents_cleaned = []
#       3 #wordlist=file_contents.split()
# ----> 4 type(wordlist)
#
# NameError: name 'wordlist' is not defined

# %%
import string

file_contents_cleaned = []
for line in file_contents:
    words =line.split(" ")
    cleaned_words = [word.strip(string.punctuation).lower() for word in words]
    cleaned_line = " ".join(cleaned_words) + "\n"
    file_contents_cleaned.append(cleaned_line)
file_contents_cleaned
# Out:
# ["\x0c\x0c                       first published by the writer's coffee shop 2011\n\n",
#  '                                    copyright © e l james 2011\n\n',
#  '\n\n',
#  'the right of e l james to be identified as the author of this work has been asserted by her\n\n',
#  '                   under the copyright amendment moral rights act 2000\n\n',
#  '\n\n',
#  ' this work is copyright apart from any use as permitted under the copyright act 1968,\n\n',
#  '  no part may be reproduced copied scanned stored in a retrieval system recorded or\n\n',
#  '  transmitted in any form or by any means without the prior written permission of the\n\n',
#  '\n\n',
#  '                                                publisher.\n\n',
#  'this book is a work of fiction names characters places and incidents are either a prod-\n\n',
#  "uct of the author's imagination or are used fictitiously any resemblance to actual people\n\n",
#  '\n\n',
# ...

# %%
wordfreq=[]
z=[]
counts=dict()

for line in file_contents_cleaned :
    words=line.split(" ")
    for x in sensitive_word:
        if x in words :
            d[x]=d[x]+1

# %%
d
# Out:
# {'fucked up': 0, 'bitch': 7, 'fuck': 70, 'kiss': 85}

# %%
z=d.keys()
print(z)
f=d.values()
print(f)
# Out:
# dict_keys(['fucked up', 'bitch', 'fuck', 'kiss'])
# dict_values([0, 7, 70, 85])

# %%
import matplotlib.pyplot as plt

# Set plot space as inline for inline plots and qt for external plots
# %matplotlib inline
plt.figure(figsize=(5,5))
plt.bar(z,f, label='Sample Data')
plt.xlabel('X Values - Categories')
plt.ylabel('Y Values - Quantities')

plt.title('Bar Plot in Matplotlib')
plt.legend()
plt.show()

# %%
import string

# %%
import matplotlib.pyplot as plt

# %%
def open_book(filepath):
    file_obj = open(filepath)
    file_contents=file_obj.readlines()
    file_obj.close()
    file_cleanR(file_contents)

# %%
def file_cleanR(file_data):
    d={"fucked up":0,"bitch":0,"fuck":0,"kiss":0}
    sensitive_word=["fucked up","bitch","fuck","kiss"]
    file_contents_cleaned = []
    for line in file_contents:
        words =line.split(" ")
        cleaned_words = [word.strip(string.punctuation).lower() for word in words]
        cleaned_line = " ".join(cleaned_words) + "\n"
        file_contents_cleaned.append(cleaned_line)
        
    for line in file_contents_cleaned :
             words=line.split(" ")
             for x in sensitive_word:
                if x in words :
                    d[x]=d[x]+1
            
        
    # %matplotlib inline
    plt.figure(figsize=(5,5))
    plt.bar(z,f, label='Sample Data')
    plt.xlabel('X Values - Categories')
    plt.ylabel('Y Values - Quantities')

    plt.title('Bar Plot in Matplotlib')
    plt.legend()
    plt.show()

# %%
file_path="C:\\Users\\SwatiTiwari\\Downloads\\fsd.txt"
open_book(file_path)

# %%
import string
dummy_file=["it's Raining man!","it's sunny. man","it's cool Woman"]
file_clean=[]
for line in dummy_file:
    words = line.split(" ")
    cleaned_words = [word.strip(string.punctuation).lower() for word in words]
    cleaned_line = " ".join(cleaned_words) + "\n"
    file_clean.append(cleaned_line)
print(file_clean)

# %%
stop_words = ["man","woman"]

# %%
d = {"man":0,"woman":0}
mc=0
for sent in file_clean:
    words = sent.split()
    
    for x in stop_words:
        if(x in words):
            d[x]=d[x]+1

# %%
d
